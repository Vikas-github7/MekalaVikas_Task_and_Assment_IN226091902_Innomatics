# %% [markdown]
# ## 1. User Login Check
# **Problem Statement:**
# Given a username and password, check whether login is successful.
#
# username = "admin"
#
# password = "1234"
#
# **Requirements:**
# - Print "Login Successful" if both username and password match
# - Otherwise print "Invalid Credentials"
#
# Real-World Application: Authentication systems

# %%
## Desired Credentials
username = "admin"
password = "1234"

## User Inputs
userid = input("Enter User Name : ")
passkey = input("Enter Password : ")

## Logic
if userid == username:
    if passkey == password:
        print("Login Successful")
    else:
        print("Invalid Credentials")
else:
    print("Invalid Credentials")
# Out:
# Enter User Name :  admin
# Enter Password :  1234
# Login Successful

# %% [markdown]
# ## 2. Pass / Fail Analyzer
# **Problem Statement:**
# Analyze student results.
#
# marks = [45, 78, 90, 33, 60]
#
# **Requirements:**
#
# - A student passes if marks ≥ 50
# - Count the total number of pass students
# - Count the total number of fail students
# - Print the final result clearly
#
# Real-World Application: Academic evaluation systems

# %%
## List of student's marks
marks = [45, 78, 90, 33, 60]

## Initialize the no. of students passed and failed as 0
no_of_pass = 0
no_of_fail = 0

## Logic
for mark in marks:
    if mark >= 50:
        no_of_pass += 1
    else:
        no_of_fail += 1

print(f"Total number of pass students: {no_of_pass}")
print(f"Total number of fail students: {no_of_fail}")
# Out:
# Total number of pass students: 3
# Total number of fail students: 2

# %% [markdown]
# ## 3. Simple Data Cleaner
#
# **Problem Statement:**
#
# Clean and standardize user names.
#
# names = [" Alice ", "bob", " CHARLIE "]
#
# **Requirements:**
# - Remove extra spaces
# - Convert all names to lowercase
# - Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
## Initial Data
names = [" Alice ", "bob", " CHARLIE "]

cleaned_names = []
for name in names:
    ## Remove extra spaces
    ## name.strip()

    ## Convert all names to lowercase
    ## name.lower()

    ## Appending the cleaned name to the new list

    cleaned_names.append(name.strip().lower())

print("cleaned list : ")
print(cleaned_names)
# Out:
# cleaned list :
# ['alice', 'bob', 'charlie']

# %% [markdown]
# ## 4. Message Length Analyzer
# **Problem Statement:**
#
# Analyze message sizes.
#
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# **Requirements:**
# - Print the length of each message
# - Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
## Input
messages = ["Hi", "Welcome to the platform", "OK"]

## Logic
for message in messages:

    ## Print length of the message
    print(f"Length of the message '{message}': {len(message)}")

    ## Flag messages longer than 10 characters
    if len(message) > 10:
        print(f"Flaged Message: {message}")
    print()
# Out:
# Length of the message 'Hi': 2
#
# Length of the message 'Welcome to the platform': 23
# Flaged Message: Welcome to the platform
#
# Length of the message 'OK': 2

# %% [markdown]
# ## 5. Error Message Detector
# **Problem Statement:**
#
# Detect error messages from system logs.
#
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# **Requirements:**
# - Count the number of "ERROR" entries
# - Print the total error count
#
# Real-World Application: Monitoring and log analysis systems

# %%
## Log Data
logs = ["INFO", "ERROR", "WARNING", "ERROR"]

## Initilize Counter
count = 0

#To detect 'ERROR' and to count it
for log in logs:
    if log == "ERROR":
        count += 1

print(f"Total 'ERROR' count is : {count}")
# Out:
# Total 'ERROR' count is : 2
